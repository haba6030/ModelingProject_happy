# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 불러오기
original_df = pd.read_csv("simulation/HBA_raw_bla_1st_original_parameters.csv")
simulated_df = pd.read_csv("simulation/HBA_raw_bla_1st_simulated_parameters.csv")

# 비교할 파라미터 목록
params_to_plot = ["w0", "w1", "w2", "w3","w4", "gamma", "alpha"]

# Plot
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(18, 10))
axes = axes.flatten()

for i, param in enumerate(params_to_plot):
    if param in original_df.columns and param in simulated_df.columns:
        x = simulated_df[param]
        y = original_df[param]

        # 표준편차가 존재하면 error bar 추가
        if f"{param}_sd" in simulated_df.columns:
            xerr = simulated_df[f"{param}_sd"]
            print(f"{param}_sd")
        else:
            xerr = None

        axes[i].errorbar(
            y, x,
            yerr=xerr,
            fmt='o', alpha=0.7, capsize=3, ecolor='gray'
        )
        axes[i].plot([min(x), max(x)], [min(x), max(x)], 'r--')  # y = x 선
        axes[i].set_title(f"Recovery of {param}")
        axes[i].set_ylabel("Simulated (mean ± SD)")
        axes[i].set_xlabel("Recovered")
    else:
        axes[i].set_visible(False)

plt.tight_layout()
plt.suptitle("Parameter Recovery Plots with ±1 SD Error Bars", fontsize=16, y=1.02)
plt.show()
# Out:
# w0_sd
# w1_sd
# w2_sd
# w3_sd
# gamma_sd

# %%
print(original_df)
print(simulated_df)
# Out:
#     Unnamed: 0  participant    w0       w1      w2      w3  gamma
# 0            0            1  0.52 -1.90000 -36.000  -1.100   0.49
# 1            1            2  0.52  0.00096  -1.900   0.054   0.50
# 2            2            3  0.52 -1.50000   2.600 -16.000   0.49
# 3            3            4  0.53 -2.00000 -24.000   8.700   0.50
# 4            4            5  0.52 -5.00000  -9.900  11.000   0.49
# ..         ...          ...   ...      ...     ...     ...    ...
# 70          70           71  0.52  3.20000 -12.000  -6.300   0.50
# 71          71           72  0.52  0.34000   2.900   6.700   0.50
# 72          72           73  0.53  4.50000   0.048  -1.400   0.49
# 73          73           74  0.52  2.60000 -13.000  -7.100   0.50
# 74          74           75  0.52  1.60000 -20.000  20.000   0.50
#
# [75 rows x 7 columns]
#     Unnamed: 0  participant    w0  w0_sd      w1  w1_sd     w2  w2_sd    w3  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 불러오기
original_df = pd.read_csv("simulation/HBA_addit_bla_1st_original_parameters.csv")
simulated_df = pd.read_csv("simulation/HBA_addit_bla_1st_simulated_parameters.csv")

# 비교할 파라미터 목록
params_to_plot = ["w0", "w1", "w2", "w3","w4", "gamma", "alpha"]

# Plot
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(18, 10))
axes = axes.flatten()

for i, param in enumerate(params_to_plot):
    if param in original_df.columns and param in simulated_df.columns:
        x = simulated_df[param]
        y = original_df[param]

        # 표준편차가 존재하면 error bar 추가
        if f"{param}_sd" in simulated_df.columns:
            xerr = simulated_df[f"{param}_sd"]
        else:
            xerr = None

        axes[i].errorbar(
            y, x,
            yerr=xerr,
            fmt='o', alpha=0.7, capsize=3, ecolor='gray'
        )
        axes[i].plot([min(x), max(x)], [min(x), max(x)], 'r--')  # y = x 선
        axes[i].set_title(f"Recovery of {param}")
        axes[i].set_ylabel("Simulated (mean ± SD)")
        axes[i].set_xlabel("Recovered")
    else:
        axes[i].set_visible(False)

plt.tight_layout()
plt.suptitle("Parameter Recovery Plots with ±1 SD Error Bars", fontsize=16, y=1.02)
plt.show()

# %%
print(original_df)
print(simulated_df)
# Out:
#     Unnamed: 0  participant    w0     w1     w2   w3  gamma  alpha
# 0            0            1  0.48  0.011  0.079  0.4   0.55   0.12
# 1            1            2  0.49  0.031  0.082  0.4   0.55   0.12
# 2            2            3  0.48  0.024  0.082  0.4   0.55   0.11
# 3            3            4  0.49 -0.026  0.083  0.4   0.55   0.11
# 4            4            5  0.48  0.018  0.081  0.4   0.56   0.11
# ..         ...          ...   ...    ...    ...  ...    ...    ...
# 70          70           71  0.48 -0.012  0.080  0.4   0.55   0.12
# 71          71           72  0.48 -0.026  0.079  0.4   0.55   0.13
# 72          72           73  0.49  0.067  0.084  0.4   0.55   0.12
# 73          73           74  0.48 -0.025  0.082  0.4   0.55   0.12
# 74          74           75  0.48  0.100  0.081  0.4   0.55   0.12
#
# [75 rows x 8 columns]
#     Unnamed: 0  participant    w0  w0_sd      w1  w1_sd    w2  w2_sd    w3  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 불러오기
original_df = pd.read_csv("simulation/HBA_phatppe_bla_2nd_original_parameters.csv")
simulated_df = pd.read_csv("simulation/HBA_phatppe_bla_2nd_simulated_parameters.csv")

# 비교할 파라미터 목록
params_to_plot = ["w0", "w1", "w2", "w3","w4", "gamma", "alpha"]

# Plot
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(18, 10))
axes = axes.flatten()

for i, param in enumerate(params_to_plot):
    if param in original_df.columns and param in simulated_df.columns:
        x = simulated_df[param]
        y = original_df[param]

        # 표준편차가 존재하면 error bar 추가
        if f"{param}_sd" in simulated_df.columns:
            xerr = simulated_df[f"{param}_sd"]
        else:
            xerr = None

        axes[i].errorbar(
            y, x,
            yerr=xerr,
            fmt='o', alpha=0.7, capsize=3, ecolor='gray'
        )
        axes[i].plot([min(x), max(x)], [min(x), max(x)], 'r--')  # y = x 선
        axes[i].set_title(f"Recovery of {param}")
        axes[i].set_ylabel("Simulated (mean ± SD)")
        axes[i].set_xlabel("Recovered")
    else:
        axes[i].set_visible(False)

plt.tight_layout()
plt.suptitle("Parameter Recovery Plots with ±1 SD Error Bars", fontsize=16, y=1.02)
plt.show()

# %%
print(original_df)
print(simulated_df)
# Out:
#     Unnamed: 0  participant     w0    w1    w2  gamma  alpha
# 0            0            1  0.033  0.28  0.28   0.48    0.5
# 1            1            2  0.093  0.29  0.28   0.48    0.5
# 2            2            3  0.085  0.29  0.28   0.50    0.5
# 3            3            4  0.160  0.29  0.28   0.50    0.5
# 4            4            5  0.047  0.29  0.28   0.52    0.5
# ..         ...          ...    ...   ...   ...    ...    ...
# 70          70           71  0.150  0.28  0.27   0.44    0.5
# 71          71           72  0.044  0.28  0.28   0.46    0.5
# 72          72           73  0.140  0.29  0.27   0.50    0.5
# 73          73           74  0.130  0.29  0.28   0.48    0.5
# 74          74           75  0.130  0.28  0.27   0.45    0.5
#
# [75 rows x 7 columns]
#     Unnamed: 0  participant      w0  w0_sd    w1  w1_sd    w2  w2_sd  gamma  \
# 0            0            1  0.4200   0.20  0.17  0.081  0.26  0.064   0.41
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 불러오기
original_df = pd.read_csv("simulation/HBA_mixed_addit_bla_2nd_original_parameters.csv")
simulated_df = pd.read_csv("simulation/HBA_mixed_addit_bla_2nd_simulated_parameters.csv")

# 비교할 파라미터 목록
params_to_plot = ["w0", "w1", "w2", "w3","w4", "gamma", "alpha"]

# Plot
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(18, 10))
axes = axes.flatten()

for i, param in enumerate(params_to_plot):
    if param in original_df.columns and param in simulated_df.columns:
        x = simulated_df[param]
        y = original_df[param]

        # 표준편차가 존재하면 error bar 추가
        if f"{param}_sd" in simulated_df.columns:
            xerr = simulated_df[f"{param}_sd"]
        else:
            xerr = None

        axes[i].errorbar(
            y, x,
            yerr=xerr,
            fmt='o', alpha=0.7, capsize=3, ecolor='gray'
        )
        axes[i].plot([min(x), max(x)], [min(x), max(x)], 'r--')  # y = x 선
        axes[i].set_title(f"Recovery of {param}")
        axes[i].set_ylabel("Simulated (mean ± SD)")
        axes[i].set_xlabel("Recovered")
    else:
        axes[i].set_visible(False)

plt.tight_layout()
plt.suptitle("Parameter Recovery Plots with ±1 SD Error Bars", fontsize=16, y=1.02)
plt.show()

# %%
print(original_df)
print(simulated_df)
# Out:
#     Unnamed: 0  participant    w0      w1     w2     w3    w4  gamma  alpha
# 0            0            1  0.48 -0.0059  0.038  0.031  0.27   0.66  0.082
# 1            1            2  0.48  0.0510  0.041  0.028  0.27   0.66  0.083
# 2            2            3  0.48  0.0210  0.039  0.029  0.27   0.66  0.082
# 3            3            4  0.48 -0.0035  0.043  0.027  0.27   0.66  0.081
# 4            4            5  0.48 -0.0094  0.040  0.035  0.27   0.66  0.082
# ..         ...          ...   ...     ...    ...    ...   ...    ...    ...
# 70          70           71  0.48 -0.0062  0.038  0.022  0.26   0.66  0.086
# 71          71           72  0.48 -0.0280  0.037  0.025  0.27   0.66  0.085
# 72          72           73  0.48  0.0490  0.043  0.027  0.27   0.66  0.079
# 73          73           74  0.48 -0.0140  0.041  0.028  0.27   0.66  0.082
# 74          74           75  0.48  0.0130  0.041  0.022  0.26   0.65  0.085
#
# [75 rows x 9 columns]
# ...
