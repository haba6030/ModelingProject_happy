# %%
import random
import numpy as np
import pandas as pd
import pymc as pm
import arviz as az

from scipy.optimize import minimize

import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel

import json

# %%
dfBlInfo = pd.read_csv("combined_participant_info.csv")
dfBlTrial = pd.read_csv("combined_trials_new.csv")
dfRtInfo = pd.read_csv("participant_info.csv")
dfRtTrial = pd.read_csv("participant_trials.csv")

# %%
dfBlTrial
# Out:
#                                       id  trial  prob1  prob2  mag1  mag2  \
# 0       P_MoodFlexi_01_Behavior10_01s2v0      1    0.2    0.8  20.0  40.0
# 1       P_MoodFlexi_01_Behavior10_01s2v0      2    0.2    0.8  10.0  60.0
# 2       P_MoodFlexi_01_Behavior10_01s2v0      3    0.2    0.8  40.0  20.0
# 3       P_MoodFlexi_01_Behavior10_01s2v0      4    0.2    0.8  10.0  80.0
# 4       P_MoodFlexi_01_Behavior10_01s2v0      5    0.2    0.8  40.0  10.0
# ...                                  ...    ...    ...    ...   ...   ...
# 11995  P_MoodFlexi_01_Behavior62_01v2s37    156    0.2    0.8  20.0  40.0
# 11996  P_MoodFlexi_01_Behavior62_01v2s37    157    0.2    0.8  60.0  10.0
# 11997  P_MoodFlexi_01_Behavior62_01v2s37    158    0.2    0.8  10.0  40.0
# 11998  P_MoodFlexi_01_Behavior62_01v2s37    159    0.2    0.8  40.0  40.0
# 11999  P_MoodFlexi_01_Behavior62_01v2s37    160    0.2    0.8  10.0  60.0
#
#        stimID  choice  happy_rating  gain_loss group context
# 0         2.0     1.0           NaN       40.0   s2v  stable
# 1         2.0     1.0           NaN       60.0   s2v  stable
# 2         1.0     0.0           NaN        0.0   s2v  stable
# 3         2.0     1.0      0.225260        0.0   s2v  stable
# 4         1.0     0.0           NaN        0.0   s2v  stable
# ...       ...     ...           ...        ...   ...     ...
# 11995     2.0     1.0           NaN       40.0   v2s  stable
# 11996     2.0     1.0      0.647135       10.0   v2s  stable
# 11997     2.0     1.0           NaN       40.0   v2s  stable
# 11998     2.0     1.0           NaN       40.0   v2s  stable
# 11999     2.0     1.0      0.816406       60.0   v2s  stable
#
# [12000 rows x 12 columns]

# %% [markdown]
# ### Blain

# %%
print(dfBlInfo.shape)
# Out:
# (75, 16)

# %%
dfBlInfo['id'].nunique()
# Out:
# 75

# %%
# depression 확인: 우울 평가가 어렵다는 한계 보유
def categorize_bdi(score):
    if pd.isna(score):
        return "missing"
    elif score <= 13:
        return "minimal"
    elif score <= 19:
        return "mild"
    elif score <= 28:
        return "moderate"
    else:
        return "severe"

# Apply categorization
dfBlInfo['BDI_category'] = dfBlInfo['BDI_bdi_score'].apply(categorize_bdi)

# Count each category
bdi_counts = dfBlInfo['BDI_category'].value_counts()
bdi_counts
# Out:
# BDI_category
# minimal     55
# mild         9
# moderate     9
# severe       2
# Name: count, dtype: int64

# %%
# PHQ로도 우울집단이 적음
def categorize_phq(score):
    if pd.isna(score):
        return "missing"
    elif score <= 4:
        return "minimal"
    elif score <= 9:
        return "mild"
    elif score <= 14:
        return "moderate"
    elif score <= 19:
        return "moderateSevere"
    else:
        return "severe"

# Apply categorization
dfBlInfo['PHQ_category'] = dfBlInfo['PHQ_PHQ_score'].apply(categorize_phq)

# Count each category
bdi_counts = dfBlInfo['PHQ_category'].value_counts()
bdi_counts
# Out:
# PHQ_category
# minimal           38
# mild              25
# moderate           9
# moderateSevere     2
# severe             1
# Name: count, dtype: int64

# %%
# 모델 피팅을 위해 CR 추가 (실험에 없으니 0으로 첨부 - 보장된 보상 없음)
dfBlTrial["CR"] = 0

# %%
print(dfBlTrial.shape) # 75*160
# Out:
# (12000, 13)

# %% [markdown]
# ### Rutledge

# %%
dfRtInfo.shape
# Out:
# (1858, 21)

# %%
dfRtInfo.head()
# Out:
#     id  age  isFemale  location  lifeSatisfaction  education  nativeLanguage  \
# 0   89    5         1       400                 7          1             1.0
# 1   92    3         0         3                 6          3             1.0
# 2  106    4         1         3                 7          3             1.0
# 3  113    4         1       400                 7          3             1.0
# 4  194    6         0       900                 6          3             1.0
#
#   deviceType  nPlays  timesPlayed  ...  timeOfDay  designVersion  depStatus  \
# 0          i       2            1  ...   0.991713              1          2
# 1          i       4            2  ...   0.898831              1          2
# 2          i       7            1  ...   0.039907              1          2
# 3          i       2            1  ...   0.079664              1          3
# 4          i       2            1  ...   0.324479              1          3
#
#    depEpisodes  depYears  depMeds  depFamily  bdiDayNumber  bdiRaw  bdiTotal
# 0            5         5        4          1           242       0         6
# 1            5         5        4          2           229       0         6
# 2            1         5        4          3           335       0         1
# 3            5         5        3          2           268       0         2
# 4            5         5        4          3           332       0         5
#
# [5 rows x 21 columns]

# %%
# Apply categorization
dfRtInfo['BDI_category'] = dfRtInfo['bdiTotal'].apply(categorize_bdi)

# Count each category
bdi_counts = dfRtInfo['BDI_category'].value_counts()
print(bdi_counts)

age_counts = dfRtInfo['age'].value_counts()
print(age_counts)

fm_counts = dfRtInfo['isFemale'].value_counts()
print(fm_counts)

fm_counts = dfRtInfo['isFemale'].value_counts()
print(fm_counts)
# Out:
# BDI_category
# minimal     1224
# mild         230
# moderate     228
# severe       176
# Name: count, dtype: int64
# age
# 3    511
# 4    375
# 1    319
# 2    283
# 5    228
# 6    129
# 7     13
# Name: count, dtype: int64
# isFemale
# 1    931
# 0    927
# Name: count, dtype: int64
# isFemale
# 1    931
# 0    927
# Name: count, dtype: int64

# %%
dfRtTrial.shape
# Out:
# (55740, 14)

# %%
dfRtTrial['prob1'] = 0.5
dfRtTrial['prob2'] = 0.5

# %%
dfRtTrial.head()
# Out:
#    id  nTrial  riskySide  certainValue  winValue  loseValue  choseRisky  \
# 0  89     1.0        1.0           0.0      40.0      -14.0         1.0
# 1  89     2.0        1.0          55.0      97.0        0.0         1.0
# 2  89     3.0        1.0         -45.0       0.0     -122.0         0.0
# 3  89     4.0        1.0         -45.0       0.0      -90.0         1.0
# 4  89     5.0        1.0          55.0     124.0        0.0         1.0
#
#    outcome  choiceRT  happiness  startValue  happinessRT  spinDuration  \
# 0     40.0     9.784       70.0        50.0        7.467         4.382
# 1     97.0     5.083        NaN         NaN          NaN         4.383
# 2    -45.0     9.600       49.0        50.0        7.349           NaN
# 3    -90.0     5.484        NaN         NaN          NaN         4.383
# 4    124.0     4.384        NaN         NaN          NaN         4.383
#
#    spinAngle  prob1  prob2
# 0      6.239    0.5    0.5
# 1      3.348    0.5    0.5
# 2        NaN    0.5    0.5
# 3      2.720    0.5    0.5
# 4      4.982    0.5    0.5

# %% [markdown]
# ## Data Modification
# - Rutledge
# 1. 확률 추가: certain(1), gamble(0.5) - prob1, prob2
# 2. 참가자별 Happiness 정규화
#
# - Blain
# 1. outcome 열 명시적으로

# %% [markdown]
# ### Rutledge

# %%
# 1. 0이 아닌 값 추출 → value1, value2 설정
def assign_values(row):
    values = [row['certainValue'], row['winValue'], row['loseValue']]
    non_zero_vals = [v for v in values if v != 0]

    # 비어 있지 않다면 앞에서 두 개를 value1, value2로 사용
    if len(non_zero_vals) >= 2:
        return pd.Series({'value1': non_zero_vals[0], 'value2': non_zero_vals[1]})
    else:
        return pd.Series({'value1': row['winValue'], 'value2': row['loseValue']}) # gamble choice = 0 경우

dfRtTrial[['value1', 'value2']] = dfRtTrial.apply(assign_values, axis=1)

# %%
# 2. case 정의: CertainValue의 부호 기준
def determine_case(val):
    if val > 0:
        return 1
    elif val < 0:
        return 3 # certain gamble
    else:
        return 2 # gamble

dfRtTrial['case'] = dfRtTrial['certainValue'].apply(determine_case)

# %%
# # 3. prob1, prob2 설정
# def assign_probs(row):
#     if row['case'] in [1, 3]:
#         return pd.Series({'prob1': 1.0, 'prob2': 0.5})
#     elif row['case'] == 2:
#         return pd.Series({'prob1': 0.5, 'prob2': 0.5})
#     else:
#         return pd.Series({'prob1': np.nan, 'prob2': np.nan})

# dfRtTrial[['prob1', 'prob2']] = dfRtTrial.apply(assign_probs, axis=1)

# %%
# 4. winLose 정의: 1 win, 0 lose, -1 not gamble
def determine_case(row):
    if row["case"] == -1:            # gamble을 선택하지 않음
        return -1
    elif row["outcome"] == row["winValue"]:  # gamble 결과가 win
        return 1
    else:                            # gamble 결과가 lose
        return 0

dfRtTrial["winLose"] = dfRtTrial.apply(determine_case, axis=1)

# %%
# 5. happiness 정규화 → 'happiness_z' 열로 저장
dfRtTrial['happiness_z'] = (
    dfRtTrial['happiness'] - dfRtTrial['happiness'].mean()
    ) / dfRtTrial['happiness'].std()

# %%
dfRtTrial = dfRtTrial.rename(columns={"certainValue": "CR"})
dfRtTrial = dfRtTrial.rename(columns={"winValue": "mag1"})
dfRtTrial = dfRtTrial.rename(columns={"loseValue": "mag2"})

dfRtTrial
# Out:
#           id  nTrial  riskySide    CR   mag1   mag2  choseRisky  outcome  \
# 0         89     1.0        1.0   0.0   40.0  -14.0         1.0     40.0
# 1         89     2.0        1.0  55.0   97.0    0.0         1.0     97.0
# 2         89     3.0        1.0 -45.0    0.0 -122.0         0.0    -45.0
# 3         89     4.0        1.0 -45.0    0.0  -90.0         1.0    -90.0
# 4         89     5.0        1.0  55.0  124.0    0.0         1.0    124.0
# ...      ...     ...        ...   ...    ...    ...         ...      ...
# 55735  44455    26.0        1.0  55.0   85.0    0.0         0.0     55.0
# 55736  44455    27.0        1.0   0.0   55.0  -63.0         0.0      0.0
# 55737  44455    28.0        1.0  45.0   79.0    0.0         0.0     45.0
# 55738  44455    29.0        1.0 -55.0    0.0  -79.0         1.0      0.0
# 55739  44455    30.0        1.0 -55.0    0.0  -66.0         1.0      0.0
#
#        choiceRT  happiness  ...  happinessRT  spinDuration  spinAngle  prob1  \
# 0         9.784       70.0  ...        7.467         4.382      6.239    0.5
# 1         5.083        NaN  ...          NaN         4.383      3.348    0.5
# 2         9.600       49.0  ...        7.349           NaN        NaN    0.5
# 3         5.484        NaN  ...          NaN         4.383      2.720    0.5
# 4         4.384        NaN  ...          NaN         4.383      4.982    0.5
# ...         ...        ...  ...          ...           ...        ...    ...
# 55735     3.532        NaN  ...          NaN           NaN        NaN    0.5
# 55736     2.865        NaN  ...          NaN           NaN        NaN    0.5
# 55737     4.566       59.0  ...        2.250           NaN        NaN    0.5
# 55738     3.284        NaN  ...          NaN        -5.582      3.603    0.5
# 55739     2.814       60.0  ...        2.098        -5.067      5.826    0.5
#
#        prob2  value1  value2  case  winLose  happiness_z
# 0        0.5    40.0   -14.0     2        1     0.762380
# 1        0.5    55.0    97.0     1        1          NaN
# 2        0.5   -45.0  -122.0     3        0    -0.372028
# 3        0.5   -45.0   -90.0     3        0          NaN
# 4        0.5    55.0   124.0     1        1          NaN
# ...      ...     ...     ...   ...      ...          ...
# 55735    0.5    55.0    85.0     1        0          NaN
# 55736    0.5    55.0   -63.0     2        0          NaN
# 55737    0.5    45.0    79.0     1        0     0.168166
# 55738    0.5   -55.0   -79.0     3        1          NaN
# 55739    0.5   -55.0   -66.0     3        1     0.222186
#
# [55740 rows x 21 columns]

# %% [markdown]
# ### Blain

# %%
# dfBlTrial['outcome'] = np.where(dfBlTrial['choice'] == 0, dfBlTrial['mag1'], dfBlTrial['mag2']) : gainloss임
dfBlTrial['winLose'] = np.where(dfBlTrial['gain_loss'] > 0, 1, 0)

# %%
dfBlTrial["choseRisky"] = 1.0
dfBlTrial
# Out:
#                                       id  trial  prob1  prob2  mag1  mag2  \
# 0       P_MoodFlexi_01_Behavior10_01s2v0      1    0.2    0.8  20.0  40.0
# 1       P_MoodFlexi_01_Behavior10_01s2v0      2    0.2    0.8  10.0  60.0
# 2       P_MoodFlexi_01_Behavior10_01s2v0      3    0.2    0.8  40.0  20.0
# 3       P_MoodFlexi_01_Behavior10_01s2v0      4    0.2    0.8  10.0  80.0
# 4       P_MoodFlexi_01_Behavior10_01s2v0      5    0.2    0.8  40.0  10.0
# ...                                  ...    ...    ...    ...   ...   ...
# 11995  P_MoodFlexi_01_Behavior62_01v2s37    156    0.2    0.8  20.0  40.0
# 11996  P_MoodFlexi_01_Behavior62_01v2s37    157    0.2    0.8  60.0  10.0
# 11997  P_MoodFlexi_01_Behavior62_01v2s37    158    0.2    0.8  10.0  40.0
# 11998  P_MoodFlexi_01_Behavior62_01v2s37    159    0.2    0.8  40.0  40.0
# 11999  P_MoodFlexi_01_Behavior62_01v2s37    160    0.2    0.8  10.0  60.0
#
#        stimID  choice  happy_rating  gain_loss group context  CR  winLose  \
# 0         2.0     1.0           NaN       40.0   s2v  stable   0        1
# 1         2.0     1.0           NaN       60.0   s2v  stable   0        1
# 2         1.0     0.0           NaN        0.0   s2v  stable   0        0
# 3         2.0     1.0      0.225260        0.0   s2v  stable   0        0
# 4         1.0     0.0           NaN        0.0   s2v  stable   0        0
# ...       ...     ...           ...        ...   ...     ...  ..      ...
# 11995     2.0     1.0           NaN       40.0   v2s  stable   0        1
# 11996     2.0     1.0      0.647135       10.0   v2s  stable   0        1
# 11997     2.0     1.0           NaN       40.0   v2s  stable   0        1
# 11998     2.0     1.0           NaN       40.0   v2s  stable   0        1
# 11999     2.0     1.0      0.816406       60.0   v2s  stable   0        1
#
#        choseRisky
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# ...           ...
# 11995         1.0
# 11996         1.0
# 11997         1.0
# 11998         1.0
# 11999         1.0
#
# [12000 rows x 15 columns]

# %%
# 2. Expected reward 정규화
# Inspect reward magnitude columns (mag1, mag2)
mag1_min, mag1_max = dfBlTrial['mag1'].min(), dfBlTrial['mag1'].max()
mag2_min, mag2_max = dfBlTrial['mag2'].min(), dfBlTrial['mag2'].max()

# Apply min-max normalization to [0, 1] scale
dfBlTrial['mag1_norm'] = (dfBlTrial['mag1'] - mag1_min) / (mag1_max - mag1_min)
dfBlTrial['mag2_norm'] = (dfBlTrial['mag2'] - mag2_min) / (mag2_max - mag2_min)

dfBlTrial["outcome"] = np.where(
    dfBlTrial["gain_loss"] == 0, 
    0,
    np.where(dfBlTrial["choice"] == 0, dfBlTrial["mag1_norm"], dfBlTrial["mag2_norm"])
)

# %%
dfBlTrial = dfBlTrial.rename(columns={"happy_rating": "happiness"})

# %%
# 5. 저장 - Norm, Norm
dfBlTrial.to_csv("Blain_trials_modified.csv", index=False)

# %%
dfBlTrial
# Out:
#                                       id  trial  prob1  prob2  mag1  mag2  \
# 0       P_MoodFlexi_01_Behavior10_01s2v0      1    0.2    0.8  20.0  40.0
# 1       P_MoodFlexi_01_Behavior10_01s2v0      2    0.2    0.8  10.0  60.0
# 2       P_MoodFlexi_01_Behavior10_01s2v0      3    0.2    0.8  40.0  20.0
# 3       P_MoodFlexi_01_Behavior10_01s2v0      4    0.2    0.8  10.0  80.0
# 4       P_MoodFlexi_01_Behavior10_01s2v0      5    0.2    0.8  40.0  10.0
# ...                                  ...    ...    ...    ...   ...   ...
# 11995  P_MoodFlexi_01_Behavior62_01v2s37    156    0.2    0.8  20.0  40.0
# 11996  P_MoodFlexi_01_Behavior62_01v2s37    157    0.2    0.8  60.0  10.0
# 11997  P_MoodFlexi_01_Behavior62_01v2s37    158    0.2    0.8  10.0  40.0
# 11998  P_MoodFlexi_01_Behavior62_01v2s37    159    0.2    0.8  40.0  40.0
# 11999  P_MoodFlexi_01_Behavior62_01v2s37    160    0.2    0.8  10.0  60.0
#
#        stimID  choice  happiness  gain_loss group context  CR  winLose  \
# 0         2.0     1.0        NaN       40.0   s2v  stable   0        1
# 1         2.0     1.0        NaN       60.0   s2v  stable   0        1
# 2         1.0     0.0        NaN        0.0   s2v  stable   0        0
# 3         2.0     1.0   0.225260        0.0   s2v  stable   0        0
# 4         1.0     0.0        NaN        0.0   s2v  stable   0        0
# ...       ...     ...        ...        ...   ...     ...  ..      ...
# 11995     2.0     1.0        NaN       40.0   v2s  stable   0        1
# 11996     2.0     1.0   0.647135       10.0   v2s  stable   0        1
# 11997     2.0     1.0        NaN       40.0   v2s  stable   0        1
# 11998     2.0     1.0        NaN       40.0   v2s  stable   0        1
# 11999     2.0     1.0   0.816406       60.0   v2s  stable   0        1
#
#        choseRisky  mag1_norm  mag2_norm   outcome
# 0             1.0   0.142857   0.428571  0.428571
# 1             1.0   0.000000   0.714286  0.714286
# 2             1.0   0.428571   0.142857  0.000000
# 3             1.0   0.000000   1.000000  0.000000
# 4             1.0   0.428571   0.000000  0.000000
# ...           ...        ...        ...       ...
# 11995         1.0   0.142857   0.428571  0.428571
# 11996         1.0   0.714286   0.000000  0.000000
# 11997         1.0   0.000000   0.428571  0.428571
# 11998         1.0   0.428571   0.428571  0.428571
# 11999         1.0   0.000000   0.714286  0.714286
#
# [12000 rows x 18 columns]

# %% [markdown]
# ### Rescale 커지게

# %%
dfBlCopy = dfBlTrial.copy()

# %%
dfBlCopy["mag1_norm"] = dfBlTrial["mag1_norm"] * 100 
dfBlCopy["mag2_norm"] = dfBlTrial["mag2_norm"] * 100 
dfBlCopy["outcome"] = dfBlTrial["outcome"] * 100

# %%
dfBlCopy["happiness"]= dfBlTrial["happiness"] * 100 - 50

# %%
dfBlCopy
# Out:
#                                       id  trial  prob1  prob2  mag1  mag2  \
# 0       P_MoodFlexi_01_Behavior10_01s2v0      1    0.2    0.8  20.0  40.0
# 1       P_MoodFlexi_01_Behavior10_01s2v0      2    0.2    0.8  10.0  60.0
# 2       P_MoodFlexi_01_Behavior10_01s2v0      3    0.2    0.8  40.0  20.0
# 3       P_MoodFlexi_01_Behavior10_01s2v0      4    0.2    0.8  10.0  80.0
# 4       P_MoodFlexi_01_Behavior10_01s2v0      5    0.2    0.8  40.0  10.0
# ...                                  ...    ...    ...    ...   ...   ...
# 11995  P_MoodFlexi_01_Behavior62_01v2s37    156    0.2    0.8  20.0  40.0
# 11996  P_MoodFlexi_01_Behavior62_01v2s37    157    0.2    0.8  60.0  10.0
# 11997  P_MoodFlexi_01_Behavior62_01v2s37    158    0.2    0.8  10.0  40.0
# 11998  P_MoodFlexi_01_Behavior62_01v2s37    159    0.2    0.8  40.0  40.0
# 11999  P_MoodFlexi_01_Behavior62_01v2s37    160    0.2    0.8  10.0  60.0
#
#        stimID  choice  happiness  gain_loss group context  CR  winLose  \
# 0         2.0     1.0        NaN       40.0   s2v  stable   0        1
# 1         2.0     1.0        NaN       60.0   s2v  stable   0        1
# 2         1.0     0.0        NaN        0.0   s2v  stable   0        0
# 3         2.0     1.0 -27.473958        0.0   s2v  stable   0        0
# 4         1.0     0.0        NaN        0.0   s2v  stable   0        0
# ...       ...     ...        ...        ...   ...     ...  ..      ...
# 11995     2.0     1.0        NaN       40.0   v2s  stable   0        1
# 11996     2.0     1.0  14.713542       10.0   v2s  stable   0        1
# 11997     2.0     1.0        NaN       40.0   v2s  stable   0        1
# 11998     2.0     1.0        NaN       40.0   v2s  stable   0        1
# 11999     2.0     1.0  31.640625       60.0   v2s  stable   0        1
#
#        choseRisky  mag1_norm   mag2_norm    outcome
# 0             1.0  14.285714   42.857143  42.857143
# 1             1.0   0.000000   71.428571  71.428571
# 2             1.0  42.857143   14.285714   0.000000
# 3             1.0   0.000000  100.000000   0.000000
# 4             1.0  42.857143    0.000000   0.000000
# ...           ...        ...         ...        ...
# 11995         1.0  14.285714   42.857143  42.857143
# 11996         1.0  71.428571    0.000000   0.000000
# 11997         1.0   0.000000   42.857143  42.857143
# 11998         1.0  42.857143   42.857143  42.857143
# 11999         1.0   0.000000   71.428571  71.428571
#
# [12000 rows x 18 columns]

# %%
dfBlCopy.to_csv("Blain_trials_rescaled.csv", index=False)

# %% [markdown]
# ### Rutledge 줄이기

# %%
# 2. Categorize BDI into clinical categories
def categorize_bdi(score):
    if score <= 13:
        return "minimal"
    elif score <= 19:
        return "mild"
    elif score <= 28:
        return "moderate"
    else:
        return "severe"

dfRtInfo["BDI_category"] = dfRtInfo["bdiTotal"].apply(categorize_bdi)

# 3. Collapse age group: 1–2 = A, 3–4 = B, 5–7 = C
def collapse_age(age_code):
    if age_code in [1, 2]:
        return "A"
    elif age_code in [3, 4]:
        return "B"
    else:
        return "C"

dfRtInfo["age_group"] = dfRtInfo["age"].apply(collapse_age)

# 4. Create stratification variable
dfRtInfo["strata"] = dfRtInfo["isFemale"].astype(str) + "_" + dfRtInfo["BDI_category"] + "_" + dfRtInfo["age_group"]

# 5. Drop missing values
dfRtInfo_clean = dfRtInfo.dropna(subset=["strata"])
dfRtInfo_unique = dfRtInfo_clean.drop_duplicates(subset="id")

# 6. Stratified sampling (500 participants)
sss = StratifiedShuffleSplit(n_splits=1, test_size=200, random_state=42)
for _, sample_idx in sss.split(dfRtInfo_unique, dfRtInfo_unique["strata"]):
    sampled_ids = dfRtInfo_unique.iloc[sample_idx]["id"].values

# 7. Subset full trials to only include those participants
dfRtTrial_sampled = dfRtTrial[dfRtTrial["id"].isin(sampled_ids)].copy()
dfRtInfo_sampled = dfRtInfo[dfRtInfo["id"].isin(sampled_ids)].copy()

# 8. (Optional) Save results
dfRtTrial_sampled.to_csv("Rutledge_sampled_trials.csv", index=False)
dfRtInfo_sampled.to_csv("Rutledge_sampled_info.csv", index=False)

# %%
print(dfRtTrial_sampled.shape)
print(dfRtInfo_sampled.shape)

# %%
# Apply categorization
dfRtInfo = dfRtInfo_sampled
dfRtInfo['BDI_category'] = dfRtInfo['bdiTotal'].apply(categorize_bdi)

# Count each category
bdi_counts = dfRtInfo['BDI_category'].value_counts()
print(bdi_counts)

age_counts = dfRtInfo['age'].value_counts()
print(age_counts)

fm_counts = dfRtInfo['isFemale'].value_counts()
print(fm_counts)

fm_counts = dfRtInfo['isFemale'].value_counts()
print(fm_counts)

# %%
# 저장
dfRtTrial_sampled.to_csv("Rutledge_trials_modified.csv", index=False)
dfRtInfo_sampled.to_csv("Rutledge_info_modified.csv", index=False)

# %% [markdown]
# ### For mini

# %%
# 6. Stratified sampling (500 participants)
sss = StratifiedShuffleSplit(n_splits=1, test_size=24, random_state=42)
for _, sample_idx in sss.split(dfRtInfo_unique, dfRtInfo_unique["strata"]):
    sampled_ids = dfRtInfo_unique.iloc[sample_idx]["id"].values
    
# 7. Subset full trials to only include those participants
dfRtTrial_sampled = dfRtTrial[dfRtTrial["id"].isin(sampled_ids)].copy()
dfRtInfo_sampled = dfRtInfo[dfRtInfo["id"].isin(sampled_ids)].copy()

# 8. (Optional) Save results
dfRtTrial_sampled.to_csv("Rutledge_trials_fortest.csv", index=False)
dfRtInfo_sampled.to_csv("Rutledge_info_fortest.csv", index=False)

print(dfRtTrial_sampled.shape)
print(dfRtInfo_sampled.shape)

# %% [markdown]
# ## Data Split

# %%
dfRtInfo = pd.read_csv("Rutledge_info_modified.csv")
dfRtTrial = pd.read_csv("Rutledge_trials_modified.csv")

# %%
dfRtInfo_low = dfRtInfo[(dfRtInfo["BDI_category"] == "minimal") | (dfRtInfo["BDI_category"] == "mild")]
dfRtInfo_low["BDI_category"].value_counts()
# Out:
# BDI_category
# minimal    133
# mild        24
# Name: count, dtype: int64

# %%
dfRtInfo_high = dfRtInfo[(dfRtInfo["BDI_category"] != "minimal") & (dfRtInfo["BDI_category"] != "mild")]
dfRtInfo_high["BDI_category"].value_counts()
# Out:
# BDI_category
# moderate    25
# severe      18
# Name: count, dtype: int64

# %%
# 1. 낮은 BDI 그룹의 ID 목록 추출
low_ids = dfRtInfo_low["id"].unique()

# 2. dfRtTrial에서 해당 ID에 해당하는 행만 필터링
dfRtTrial_low = dfRtTrial[dfRtTrial["id"].isin(low_ids)]
dfRtTrial_low
# Out:
#          id  nTrial  riskySide    CR   mag1  mag2  choseRisky  outcome  \
# 0      1105     1.0        1.0   0.0   55.0 -35.0         1.0     55.0
# 1      1105     2.0        1.0 -45.0    0.0 -85.0         0.0    -45.0
# 2      1105     3.0        1.0 -30.0    0.0 -96.0         0.0    -30.0
# 3      1105     4.0        1.0  45.0   85.0   0.0         1.0     85.0
# 4      1105     5.0        1.0  55.0  103.0   0.0         0.0     55.0
# ...     ...     ...        ...   ...    ...   ...         ...      ...
# 5965  44160    26.0        1.0   0.0   75.0 -37.0         1.0     75.0
# 5966  44160    27.0        1.0 -35.0    0.0 -66.0         1.0    -66.0
# 5967  44160    28.0        1.0  55.0   92.0   0.0         1.0     92.0
# 5968  44160    29.0        1.0 -35.0    0.0 -66.0         1.0    -66.0
# 5969  44160    30.0        1.0   0.0   40.0 -72.0         0.0      0.0
#
#       choiceRT  happiness  ...  happinessRT  spinDuration  spinAngle  prob1  \
# 0        8.293       79.0  ...        7.600         4.396      4.945    0.5
# 1        7.499        NaN  ...          NaN           NaN        NaN    0.5
# 2        4.440       77.0  ...        5.922           NaN        NaN    0.5
# 3        3.820        NaN  ...          NaN         4.416      3.186    0.5
# 4        6.981        NaN  ...          NaN           NaN        NaN    0.5
# ...        ...        ...  ...          ...           ...        ...    ...
# 5965     3.167        NaN  ...          NaN        -4.083      4.256    0.5
# 5966     3.033        NaN  ...          NaN        -5.434      2.801    0.5
# 5967     3.317       64.0  ...        2.433        -5.367      4.665    0.5
# 5968     5.133        NaN  ...          NaN        -4.202      1.026    0.5
# 5969     4.200       54.0  ...        3.916           NaN        NaN    0.5
#
#       prob2  value1  value2  case  winLose  happiness_z
# 0       0.5    55.0   -35.0     2        1     1.248555
# 1       0.5   -45.0   -85.0     3        0          NaN
# 2       0.5   -30.0   -96.0     3        0     1.140516
# 3       0.5    45.0    85.0     1        1          NaN
# 4       0.5    55.0   103.0     1        0          NaN
# ...     ...     ...     ...   ...      ...          ...
# 5965    0.5    75.0   -37.0     2        1          NaN
# 5966    0.5   -35.0   -66.0     3        0          NaN
# 5967    0.5    55.0    92.0     1        1     0.438263
# 5968    0.5   -35.0   -66.0     3        0          NaN
# 5969    0.5    40.0   -72.0     2        0    -0.101931
#
# [4710 rows x 21 columns]

# %%
# 1. 낮은 BDI 그룹의 ID 목록 추출
high_ids = dfRtInfo_high["id"].unique()

# 2. dfRtTrial에서 해당 ID에 해당하는 행만 필터링
dfRtTrial_high = dfRtTrial[dfRtTrial["id"].isin(high_ids)]
dfRtTrial_high
# Out:
#          id  nTrial  riskySide    CR   mag1   mag2  choseRisky  outcome  \
# 180    4344     1.0        1.0 -35.0    0.0  -64.0         1.0      0.0
# 181    4344     2.0        1.0 -30.0    0.0  -96.0         1.0      0.0
# 182    4344     3.0        1.0 -35.0    0.0 -112.0         1.0      0.0
# 183    4344     4.0        1.0   0.0   40.0   -8.0         0.0      0.0
# 184    4344     5.0        1.0   0.0   40.0   -8.0         1.0     -8.0
# ...     ...     ...        ...   ...    ...    ...         ...      ...
# 5995  44217    26.0        1.0  55.0  105.0    0.0         1.0    105.0
# 5996  44217    27.0        1.0 -55.0    0.0  -66.0         1.0    -66.0
# 5997  44217    28.0        1.0  45.0  124.0    0.0         1.0    124.0
# 5998  44217    29.0        1.0  45.0   85.0    0.0         1.0     85.0
# 5999  44217    30.0        1.0 -55.0    0.0  -72.0         1.0      0.0
#
#       choiceRT  happiness  ...  happinessRT  spinDuration  spinAngle  prob1  \
# 180      3.985       84.0  ...        5.883         4.382      5.359    0.5
# 181      2.401        NaN  ...          NaN         4.382      4.228    0.5
# 182      5.383       89.0  ...        3.800         4.383      5.233    0.5
# 183      2.116        NaN  ...          NaN           NaN        NaN    0.5
# 184      1.601        NaN  ...          NaN         4.382      0.207    0.5
# ...        ...        ...  ...          ...           ...        ...    ...
# 5995     4.450        NaN  ...          NaN        -4.917      6.134    0.5
# 5996     3.460        NaN  ...          NaN         3.935      2.081    0.5
# 5997     3.432       74.0  ...        5.999         4.434      5.958    0.5
# 5998     3.419        NaN  ...          NaN        -4.099      3.873    0.5
# 5999     5.433       85.0  ...        4.701        -4.517      3.739    0.5
#
#       prob2  value1  value2  case  winLose  happiness_z
# 180     0.5   -35.0   -64.0     3        1     1.518652
# 181     0.5   -30.0   -96.0     3        1          NaN
# 182     0.5   -35.0  -112.0     3        1     1.788749
# 183     0.5    40.0    -8.0     2        0          NaN
# 184     0.5    40.0    -8.0     2        0          NaN
# ...     ...     ...     ...   ...      ...          ...
# 5995    0.5    55.0   105.0     1        1          NaN
# 5996    0.5   -55.0   -66.0     3        0          NaN
# 5997    0.5    45.0   124.0     1        1     0.978457
# 5998    0.5    45.0    85.0     1        1          NaN
# 5999    0.5   -55.0   -72.0     3        1     1.572671
#
# [1290 rows x 21 columns]

# %%
# 저장
dfRtTrial_low.to_csv("Rutledge_trials_lowBDI.csv", index=False)
dfRtInfo_low.to_csv("Rutledge_info_lowBDI.csv", index=False)

dfRtTrial_high.to_csv("Rutledge_trials_highBDI.csv", index=False)
dfRtInfo_high.to_csv("Rutledge_info_highBDI.csv", index=False)

## Then, use separately for the best model

# %% [markdown]
# ### Blain

# %%
dfBlInfoS2v = pd.read_csv("stable2volatile_participant_info.csv")
dfBlTrialS2v = pd.read_csv("s2v_new_trial_data.csv")

# %%
dfBlInfoV2s = pd.read_csv("volatile2stable_participant_info.csv")
dfBlTrialV2s = pd.read_csv("v2s_new_trial_data.csv")

# %%
## Then, use it as mu = w0 * bdi_group[i] + ... for the best model
